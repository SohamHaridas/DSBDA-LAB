# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
display(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
columns = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
df.columns = columns

# %%
summary_stats = df.groupby("species").agg(['mean', 'median', 'min', 'max', 'std'])
print("Summary Statistics Grouped by Species:\n", summary_stats)
# Out:
# Summary Statistics Grouped by Species:
#                  sepal_length                            sepal_width         \
#                         mean median  min  max       std        mean median
# species
# Iris-setosa         5.004082    5.0  4.3  5.8  0.355879    3.416327    3.4
# Iris-versicolor     5.936000    5.9  4.9  7.0  0.516171    2.770000    2.8
# Iris-virginica      6.588000    6.5  4.9  7.9  0.635880    2.974000    3.0
#
#                                     petal_length                             \
#                  min  max       std         mean median  min  max       std
# species
# Iris-setosa      2.3  4.4  0.384787     1.465306   1.50  1.0  1.9  0.175061
# Iris-versicolor  2.0  3.4  0.313798     4.260000   4.35  3.0  5.1  0.469911
# Iris-virginica   2.2  3.8  0.322497     5.552000   5.55  4.5  6.9  0.551895
#
#                 petal_width
#                        mean median  min  max       std
# species
# ...

# %%
for species in df["species"].unique():
    species_data = df[df["species"] == species].describe()
    print(f"\nStatistics for {species}:\n", species_data)
# Out:
# Statistics for Iris-setosa:
#         sepal_length  sepal_width  petal_length  petal_width
# count     49.000000    49.000000     49.000000    49.000000
# mean       5.004082     3.416327      1.465306     0.244898
# std        0.355879     0.384787      0.175061     0.108130
# min        4.300000     2.300000      1.000000     0.100000
# 25%        4.800000     3.100000      1.400000     0.200000
# 50%        5.000000     3.400000      1.500000     0.200000
# 75%        5.200000     3.700000      1.600000     0.300000
# max        5.800000     4.400000      1.900000     0.600000
#
# Statistics for Iris-versicolor:
#         sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...

# %%
numerical_df = df.select_dtypes(include=[np.number])  # Select only numeric columns

mean_values = numerical_df.mean()
median_values = numerical_df.median()
mode_values = numerical_df.mode().iloc[0]

print("\nMean Values:\n", mean_values)
print("\nMedian Values:\n", median_values)
print("\nMode Values:\n", mode_values)
# Out:
# Mean Values:
#  sepal_length    5.848322
# sepal_width     3.051007
# petal_length    3.774497
# petal_width     1.205369
# dtype: float64
#
# Median Values:
#  sepal_length    5.8
# sepal_width     3.0
# petal_length    4.4
# petal_width     1.3
# dtype: float64
#
# Mode Values:
#  sepal_length    5.0
# sepal_width     3.0
# petal_length    1.5
# petal_width     0.2
# Name: 0, dtype: float64

# %%
std_values = numerical_df.std()
print("\nStandard Deviation Values:\n", std_values)
# Out:
# Standard Deviation Values:
#  sepal_length    0.828594
# sepal_width     0.433499
# petal_length    1.759651
# petal_width     0.761292
# dtype: float64

# %%
percentiles = numerical_df.quantile([0.25, 0.5, 0.75])
print("\nPercentile Values:\n", percentiles)
# Out:
# Percentile Values:
#        sepal_length  sepal_width  petal_length  petal_width
# 0.25           5.1          2.8           1.6          0.3
# 0.50           5.8          3.0           4.4          1.3
# 0.75           6.4          3.3           5.1          1.8

# %%
df['petal_length'].mean()
# Out:
# 3.774496644295302

# %%
df['petal_length'].median()
# Out:
# 4.4

# %%
df['petal_length'].mode()
# Out:
# 0    1.5
# Name: petal_length, dtype: float64

# %%
df['petal_length'].std()
# Out:
# 1.7596511617753423

# %%
 df['petal_length'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    1.6
# 0.50    4.4
# 0.75    5.1
# Name: petal_length, dtype: float64

# %%
q1=np.percentile(df['petal_length'],25)
q3=np.percentile(df['petal_length'],75)
iqr=q3-q1
print(iqr)
# Out:
# 3.4999999999999996
